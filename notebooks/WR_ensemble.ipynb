# %% [markdown]
# # Illustrates the use of the WR (Weather Regime) class for an ENSEMBLE of proxies

# %%
# %matplotlib inline

# %%
import os 
import sys
import pathlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### import the development version of paleopy

# %%
from paleopy import analogs
from paleopy import ensemble
from paleopy import WR

# %% [markdown]
# ### determine the current working directory

# %%
cwd = pathlib.Path.cwd()

# %%
print(cwd)
# Out:
# /home/nicolasf/research/PICT_notebooks/notebooks

# %% [markdown]
# #### defines the folder where the JSON files are (for the datasets) and where the proxy JSON files are located

# %%
djsons = cwd.parent.joinpath('jsons')

# %%
pjsons = djsons.joinpath('proxies')

# %% [markdown]
# ### defines the name of the directory (contained in djsons / proxies) where the proxies constituting the ensemble are defined

# %%
ens_dir_name = 'LIANZSWP'

# %%
ens_jsons = pjsons / ens_dir_name

# %%
if not ens_jsons.exists(): 
    print(f"ERROR, the directory {ens_jsons} does not exists")

# %% [markdown]
# ### first instantiates an `ensemble' class, passing the directory containing the proxy JSON files, and the season (this is needed to test for consistency between the proxies)

# %%
ens = ensemble(pjsons=ens_jsons, season='DJF')

# %% [markdown]
# ### Now instantiates a `WR` (Weather Regime) class, passing the newly created ensemble object, and the classification of interest

# %%
w = WR(ens, classification='New Zealand (Rampal et al. 2022)')

# %% [markdown]
# ### plots the barplot of the regimes climatological frequencies, and the distribution of frequency anomalies accross all the proxies as boxplots

# %% [markdown]
# ### The horizontal line for each boxplot is the median (accross all the proxies), the black circle the average, and if the anomalies are significant at the level specified in percentage (argument `sig` to the `plot_bar` method, e.g. 10 = 90%) then the box (marking the interquartile range) is highlighted in black

# %%
f = w.plot_bar(sig=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 f = w.plot_bar(sig=10)
#
# File ~/research/PICT_notebooks/src/paleopy/core/WR.py:211, in WR.plot_bar(self, sig)
#     210 def plot_bar(self, sig=10):
# --> 211     f = bar(self, sig)
#     212     return f
#
# File ~/research/PICT_notebooks/src/paleopy/plotting/bar.py:76, in bar(wr, sig)
#      73     elif wrone.df_anoms.iloc[i,:].values < 0 and not testb[i]:
#      74        plt.setp(b,facecolor='steelblue', edgecolor='k', alpha=0.5)
# ---> 76     plt.plot(i+1,wrone.df_anoms.iloc[i,:]*100, 'ko', zorder=11)
#      78 plt.setp(bp['fliers'], color='gray', marker='+',visible=True)
#      80 plt.setp(bp['medians'],color='k',linewidth=1)
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/matplotlib/pyplot.py:3019, in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1605, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1363 """
#    1364 Plot y versus x as lines and/or markers.
#    1365
#    (...)
#    1602 (``'green'``) or hex strings (``'#008000'``).
#    1603 """
#    1604 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606 for line in lines:
#    1607     self.add_line(line)
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/matplotlib/axes/_base.py:315, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     313     this += args[0],
#     314     args = args[1:]
# --> 315 yield from self._plot_args(this, kwargs)
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/matplotlib/axes/_base.py:491, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     489 if len(xy) == 2:
#     490     x = _check_1d(xy[0])
# --> 491     y = _check_1d(xy[1])
#     492 else:
#     493     x, y = index_of(xy[-1])
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1362, in _check_1d(x)
#    1356 with warnings.catch_warnings(record=True) as w:
#    1357     warnings.filterwarnings(
#    1358         "always",
#    1359         category=Warning,
#    1360         message='Support for multi-dimensional indexing')
# -> 1362     ndim = x[:, None].ndim
#    1363     # we have definitely hit a pandas index or series object
#    1364     # cast to a numpy array.
#    1365     if len(w) > 0:
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/pandas/core/series.py:1033, in Series.__getitem__(self, key)
#    1030     key = np.asarray(key, dtype=bool)
#    1031     return self._get_values(key)
# -> 1033 return self._get_with(key)
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/pandas/core/series.py:1048, in Series._get_with(self, key)
#    1043     raise TypeError(
#    1044         "Indexing a Series with DataFrame is not "
#    1045         "supported, use the appropriate DataFrame column"
#    1046     )
#    1047 elif isinstance(key, tuple):
# -> 1048     return self._get_values_tuple(key)
#    1050 elif not is_list_like(key):
#    1051     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1052     return self.loc[key]
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/pandas/core/series.py:1082, in Series._get_values_tuple(self, key)
#    1077 if com.any_none(*key):
#    1078     # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1079     #  see tests.series.timeseries.test_mpl_compat_hack
#    1080     # the asarray is needed to avoid returning a 2D DatetimeArray
#    1081     result = np.asarray(self._values[key])
# -> 1082     disallow_ndim_indexing(result)
#    1083     return result
#    1085 if not isinstance(self.index, MultiIndex):
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/pandas/core/indexers/utils.py:343, in disallow_ndim_indexing(result)
#     335 """
#     336 Helper function to disallow multi-dimensional indexing on 1D Series/Index.
#     337
#    (...)
#     340 in GH#30588.
#     341 """
#     342 if np.ndim(result) > 1:
# --> 343     raise ValueError(
#     344         "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     345         "supported. Convert to a numpy array before indexing instead."
#     346     )
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %% [markdown]
# ### heat map with individual proxies on the y-axis, the frequency anomalies significant at the 95% level are marked by the squares, the anomalies significant at the 99% level are marked by the thick circles

# %%
f = w.plot_heatmap()

# %% [markdown]
# ### same example as above but for the SW Pacific weather regimes

# %%
w = WR(ens, classification='SW Pacific (Lorrey and Fauchereau 2018)')

# %% [markdown]
# ### The horizontal line for each boxplot is the median (accross all the proxies), the black circle the average, and if the anomalies are significant at the level specified (argument `sig` to the `plot_bar` method, e.g. 10 = 90%) then the box (marking the interquartile range) then the box (marking the interquartile range) is highlighted in black

# %%
f = w.plot_bar(sig=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 f = w.plot_bar(sig=10)
#
# File ~/research/PICT_notebooks/src/paleopy/core/WR.py:211, in WR.plot_bar(self, sig)
#     210 def plot_bar(self, sig=10):
# --> 211     f = bar(self, sig)
#     212     return f
#
# File ~/research/PICT_notebooks/src/paleopy/plotting/bar.py:76, in bar(wr, sig)
#      73     elif wrone.df_anoms.iloc[i,:].values < 0 and not testb[i]:
#      74        plt.setp(b,facecolor='steelblue', edgecolor='k', alpha=0.5)
# ---> 76     plt.plot(i+1,wrone.df_anoms.iloc[i,:]*100, 'ko', zorder=11)
#      78 plt.setp(bp['fliers'], color='gray', marker='+',visible=True)
#      80 plt.setp(bp['medians'],color='k',linewidth=1)
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/matplotlib/pyplot.py:3019, in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1605, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1363 """
#    1364 Plot y versus x as lines and/or markers.
#    1365
#    (...)
#    1602 (``'green'``) or hex strings (``'#008000'``).
#    1603 """
#    1604 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606 for line in lines:
#    1607     self.add_line(line)
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/matplotlib/axes/_base.py:315, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     313     this += args[0],
#     314     args = args[1:]
# --> 315 yield from self._plot_args(this, kwargs)
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/matplotlib/axes/_base.py:491, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     489 if len(xy) == 2:
#     490     x = _check_1d(xy[0])
# --> 491     y = _check_1d(xy[1])
#     492 else:
#     493     x, y = index_of(xy[-1])
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1362, in _check_1d(x)
#    1356 with warnings.catch_warnings(record=True) as w:
#    1357     warnings.filterwarnings(
#    1358         "always",
#    1359         category=Warning,
#    1360         message='Support for multi-dimensional indexing')
# -> 1362     ndim = x[:, None].ndim
#    1363     # we have definitely hit a pandas index or series object
#    1364     # cast to a numpy array.
#    1365     if len(w) > 0:
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/pandas/core/series.py:1033, in Series.__getitem__(self, key)
#    1030     key = np.asarray(key, dtype=bool)
#    1031     return self._get_values(key)
# -> 1033 return self._get_with(key)
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/pandas/core/series.py:1048, in Series._get_with(self, key)
#    1043     raise TypeError(
#    1044         "Indexing a Series with DataFrame is not "
#    1045         "supported, use the appropriate DataFrame column"
#    1046     )
#    1047 elif isinstance(key, tuple):
# -> 1048     return self._get_values_tuple(key)
#    1050 elif not is_list_like(key):
#    1051     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1052     return self.loc[key]
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/pandas/core/series.py:1082, in Series._get_values_tuple(self, key)
#    1077 if com.any_none(*key):
#    1078     # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1079     #  see tests.series.timeseries.test_mpl_compat_hack
#    1080     # the asarray is needed to avoid returning a 2D DatetimeArray
#    1081     result = np.asarray(self._values[key])
# -> 1082     disallow_ndim_indexing(result)
#    1083     return result
#    1085 if not isinstance(self.index, MultiIndex):
#
# File ~/mambaforge/envs/PICT/lib/python3.9/site-packages/pandas/core/indexers/utils.py:343, in disallow_ndim_indexing(result)
#     335 """
#     336 Helper function to disallow multi-dimensional indexing on 1D Series/Index.
#     337
#    (...)
#     340 in GH#30588.
#     341 """
#     342 if np.ndim(result) > 1:
# --> 343     raise ValueError(
#     344         "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     345         "supported. Convert to a numpy array before indexing instead."
#     346     )
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %%
f = w.plot_heatmap()

# %%
w.df_probs
# Out:
#        Caples    Jollie  Rarotonga    Fraser   Cameron      Gunn  Falls Creek  \
# SW1  0.206022  0.229430   0.166403  0.237342  0.224684  0.199052     0.236967
# SW2  0.129952  0.091772   0.120444  0.104430  0.093354  0.120063     0.093207
# SW3  0.128368  0.166139   0.109350  0.151899  0.186709  0.142180     0.157978
# SW4  0.141046  0.098101   0.218700  0.161392  0.091772  0.154818     0.112164
# SW5  0.139461  0.170886   0.120444  0.120253  0.174051  0.153239     0.170616
# SW6  0.255151  0.243671   0.264659  0.224684  0.229430  0.230648     0.229068
#
#          Cass  Browning Creek    Amedee  ...   Frances     Oroko    Hunter  \
# SW1  0.251981        0.183544  0.212361  ...  0.206022  0.199052  0.183544
# SW2  0.115689        0.099684  0.098257  ...  0.129952  0.120063  0.099684
# SW3  0.129952        0.177215  0.193344  ...  0.128368  0.142180  0.177215
# SW4  0.161648        0.117089  0.115689  ...  0.141046  0.154818  0.117089
# SW5  0.106181        0.151899  0.131537  ...  0.139461  0.153239  0.151899
# SW6  0.234548        0.270570  0.248811  ...  0.255151  0.230648  0.270570
#
#       Mistake    Temple  Taramakau     Avoca    Clarke  Turnbull   Hopkins
# SW1  0.236967  0.257911   0.224684  0.200949  0.183544  0.183544  0.183544
# SW2  0.093207  0.120253   0.093354  0.121835  0.099684  0.099684  0.099684
# SW3  0.157978  0.147152   0.186709  0.125000  0.177215  0.177215  0.177215
# SW4  0.112164  0.120253   0.091772  0.147152  0.117089  0.117089  0.117089
# SW5  0.170616  0.164557   0.174051  0.147152  0.151899  0.151899  0.151899
# SW6  0.229068  0.189873   0.229430  0.257911  0.270570  0.270570  0.270570
#
# [6 rows x 24 columns]
