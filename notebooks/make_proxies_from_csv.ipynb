# %% [markdown]
# # create a set of proxies from a CSV file containing the relevant information for each proxy

# %%
# %matplotlib inline

# %%
import os 
import sys
import pathlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### import the development version of paleopy

# %%
from paleopy import proxy 
from paleopy import analogs
from paleopy.plotting import scalar_plot

# %% [markdown]
# ### determine the current working directory

# %%
cwd = pathlib.Path.cwd()

# %%
print(cwd)
# Out:
# /home/nicolasf/research/PICT_notebooks/notebooks

# %% [markdown]
# #### defines the folder where the JSON files are (for the datasets) and where to save the proxy JSON files

# %%
djsons = cwd.parent.joinpath('jsons')

# %%
pjsons = djsons.joinpath('proxies')

# %%
djsons.mkdir(parents=True, exist_ok=True)

# %%
pjsons.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### defines the name of the directory (contained in djsons / proxies) where the ensemble will be saved, and creates it if not already existing

# %%
ens_dir_name = 'LIANZSWP'

# %%
ens_jsons = pjsons.joinpath(ens_dir_name)

# %%
ens_jsons.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### read the the  information for each proxy from a csv file

# %%
proxies = pd.read_csv('../excel//Proxies_list.csv')

# %%
proxies.head()
# Out:
#     sitename        lat         lon  value dataset variable measurement  \
# 0  Rarotonga -21.230000 -159.820000   0.60   ersst      sst   delta O18
# 1     Amedee -22.480000  166.470000  -0.26   ersst      sst   delta O18
# 2      Oroko -43.222615  170.307329  -0.42    ncep    TMean   delta O18
# 3   Greenlaw -43.006108  171.419497  -0.26    ncep    TMean   delta O18
# 4       Crow -43.346222  170.998122  -0.62    ncep    TMean   delta O18
#
#   dating_convention   calendar chronology season  qualitative  calc_anoms  \
# 0          absolute  gregorian   historic    DJF            0           1
# 1          absolute  gregorian   historic    DJF            0           1
# 2          absolute  gregorian   historic    DJF            0           1
# 3          absolute  gregorian   historic    DJF            0           1
# 4          absolute  gregorian   historic    DJF            0           1
#
#    detrend     method
# 0        1  quintiles
# 1        2  quintiles
# 2        3  quintiles
# 3        4  quintiles
# 4        5  quintiles

# %% [markdown]
# ### The code below loops over each row, instantiates a proxy instance, find the analog years, then saves the data and metadata to disk in a json file in the ensemble directory name

# %%
for i, row in proxies.iterrows(): 
    p = proxy(sitename= row['sitename'], \
          lon = row['lon'], \
          lat = row['lat'], \
          djsons = djsons, \
          pjsons = ens_jsons, \
          pfname = '{}.json'.format(row['sitename']), \
          dataset = row['dataset'], \
          variable = row['variable'], \
          measurement = row['measurement'], \
          dating_convention = row['dating_convention'], \
          calendar = row['calendar'],\
          chronology = row['chronology'], \
          season = row['season'], \
          value = row['value'], \
          qualitative = row['qualitative'], \
          calc_anoms = row['calc_anoms'], \
          detrend = row['detrend'], \
          method = row['method'])
    p.find_analogs()
    p.proxy_repr(pprint=True, outfile=True)
# Out:
# {
# sitename:Rarotonga
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(200.18, -21.23)
# aspect:None
# elevation:None
# season:DJF
# dataset:ersst
# variable:sst
# calc_anoms:True
# detrend:True
# value:0.6
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[200.0, -22.0]
# distance_point:87.56368858840081
# trend_params:{'slope': 0.03254089836312946, 'intercept': -64.96142370346887}
# category:WA
# analog_years:[1982, 1997, 1999, 2000, 2001, 2006, 2009]
# weights:[0.15378256674309246, 0.1556824020345763, 0.09780756229126657, 0.1241568749877504, 0.16163831234560427, 0.14973348587014138, 0.1571987957275686]
# }
# {
# sitename:Amedee
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(166.47, -22.48)
# aspect:None
# elevation:None
# season:DJF
# dataset:ersst
# variable:sst
# calc_anoms:True
# detrend:True
# value:-0.26
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[166.0, -22.0]
# distance_point:71.98760982961697
# trend_params:{'slope': 0.0063796006887455485, 'intercept': -12.711479941937098}
# category:B
# analog_years:[1987, 1992, 1997, 2003, 2005, 2010, 2013]
# weights:[0.14752171529415328, 0.16154269944677555, 0.1277555799077663, 0.15786926242564195, 0.1228461129998119, 0.13623549694001902, 0.14622913298583204]
# }
# {
# sitename:Oroko
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.307329, -43.222615)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.42
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -42.5]
# distance_point:84.11208434388203
# trend_params:{'slope': -0.011017740429505127, 'intercept': 22.053221288515395}
# category:B
# analog_years:[1984, 1988, 2000, 2002, 2005, 2009, 2010]
# weights:[0.1036285064606155, 0.12080652635435969, 0.15449441229403071, 0.1608526505232075, 0.1629433254663607, 0.15022684900800715, 0.14704772989341877]
# }
# {
# sitename:Greenlaw
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.419497, -43.006108)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.26
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[172.5, -42.5]
# distance_point:104.57596044098004
# trend_params:{'slope': -0.018860877684407102, 'intercept': 37.71914098972924}
# category:N
# analog_years:[1980, 1987, 1988, 1990, 1998, 2001, 2008]
# weights:[0.16642257639242367, 0.134382790983018, 0.15636396862069457, 0.13042774536293758, 0.1431804832204256, 0.13922543760034464, 0.1299969978201561]
# }
# {
# sitename:Crow
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.998122, -43.346222)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.62
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -42.5]
# distance_point:124.25433418836984
# trend_params:{'slope': -0.011017740429505127, 'intercept': 22.053221288515395}
# category:B
# analog_years:[1984, 1988, 2000, 2002, 2005, 2009, 2010]
# weights:[0.16454812244285894, 0.12549322023006276, 0.14856371698476958, 0.14603603024655654, 0.14224450013923698, 0.13718912666281088, 0.13592528329370435]
# }
# {
# sitename:Cameron
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.505139, -42.934067)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.81
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[172.5, -42.5]
# distance_point:94.46733893961293
# trend_params:{'slope': -0.018860877684407102, 'intercept': 37.71914098972924}
# category:WB
# analog_years:[1983, 1984, 1993, 2003, 2004, 2005, 2007]
# weights:[0.1611765028406295, 0.16280524875465396, 0.11989343808911045, 0.13618089722935814, 0.16659490508926653, 0.13943838905740769, 0.11391061893957377]
# }
# {
# sitename:Avoca
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.405812, -43.043031)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.53
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[172.5, -42.5]
# distance_point:107.73975744104352
# trend_params:{'slope': -0.018860877684407102, 'intercept': 37.71914098972924}
# category:B
# analog_years:[1991, 1992, 1994, 1997, 2000, 2002, 2010]
# weights:[0.14252329707740716, 0.13682685310739776, 0.13281017089332, 0.1230970447092316, 0.16272852293163306, 0.16412939294564174, 0.13788471833536864]
# }
# {
# sitename:Temple
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.709872, -44.146466)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.79
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:97.58982094997447
# trend_params:{'slope': -0.006722689075630255, 'intercept': 13.507749766573301}
# category:WB
# analog_years:[1983, 1984, 1993, 2002, 2003, 2004, 2007]
# weights:[0.11365185976695684, 0.15872385895283161, 0.13790600247629708, 0.14156956529113449, 0.14197662782611642, 0.1625672077206194, 0.14360487796604418]
# }
# {
# sitename:Hopkins
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.887499, -43.942569)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.39
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:117.84526868991945
# trend_params:{'slope': -0.006722689075630255, 'intercept': 13.507749766573301}
# category:B
# analog_years:[1991, 1992, 1995, 1997, 2000, 2001, 2005]
# weights:[0.13224821973550352, 0.14830755319056443, 0.14517741781220933, 0.14309066089330594, 0.14163862587056886, 0.14268200433002057, 0.14685551816782738]
# }
# {
# sitename:Turnbull
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.850303, -43.877607)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.4
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:125.29023646426968
# trend_params:{'slope': -0.006722689075630255, 'intercept': 13.507749766573301}
# category:B
# analog_years:[1991, 1992, 1995, 1997, 2000, 2001, 2005]
# weights:[0.13349131121642965, 0.14656836931718456, 0.1434088116552572, 0.14130243988063898, 0.14296998420221166, 0.14402317008952076, 0.14823591363875718]
# }
# {
# sitename:Jollie
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.33, -43.697778)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.99
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -42.5]
# distance_point:135.76947455586478
# trend_params:{'slope': -0.011017740429505127, 'intercept': 22.053221288515395}
# category:WB
# analog_years:[1983, 1991, 1992, 1993, 2003, 2004, 2007]
# weights:[0.12356336731646701, 0.15406921503155274, 0.15261314754899422, 0.1511570800664362, 0.1526847169676282, 0.1351403377582978, 0.1307721353106237]
# }
# {
# sitename:Cass
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.315493, -43.652675)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.16
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -42.5]
# distance_point:130.62568491574098
# trend_params:{'slope': -0.011017740429505127, 'intercept': 22.053221288515395}
# category:N
# analog_years:[1980, 1994, 1995, 1997, 1998, 2001, 2014]
# weights:[0.1325952216983636, 0.09613109427698562, 0.16100722219279162, 0.16621638325298835, 0.1645123695502466, 0.15669862795995151, 0.1228390810686727]
# }
# {
# sitename:Caples
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.182845, -44.801851)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.35
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:58.084070977038905
# trend_params:{'slope': 0.003267973856209143, 'intercept': -6.481699346405213}
# category:B
# analog_years:[1995, 1997, 1998, 2000, 2002, 2003, 2004]
# weights:[0.14922633097298707, 0.1466037241017571, 0.1452924206661421, 0.14266981379491211, 0.14004720692368214, 0.13873590348806716, 0.1374246000524522]
# }
# {
# sitename:Fraser
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.186884, -44.786354)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.21
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:59.056131286896935
# trend_params:{'slope': 0.003267973856209143, 'intercept': -6.481699346405213}
# category:N
# analog_years:[1980, 1988, 2005, 2009, 2010, 2011, 2014]
# weights:[0.1452228940284414, 0.1480416613814779, 0.15403154200668048, 0.15544092568319873, 0.11985398785111269, 0.12020633377024226, 0.15720265527884653]
# }
# {
# sitename:Frances
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.395713, -44.596521)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.41
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:83.65886439139706
# trend_params:{'slope': 0.003267973856209143, 'intercept': -6.481699346405213}
# category:B
# analog_years:[1995, 1997, 1998, 2000, 2002, 2003, 2004]
# weights:[0.12242042672263097, 0.13990905911157825, 0.14865337530605188, 0.16614200769499918, 0.14970269324938687, 0.14095837705491324, 0.1322140608604396]
# }
# {
# sitename:Hunter
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.646667, -44.094444)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.88
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:104.4478564149211
# trend_params:{'slope': -0.006722689075630255, 'intercept': 13.507749766573301}
# category:WB
# analog_years:[1983, 1984, 1993, 2002, 2003, 2004, 2007]
# weights:[0.11088568518872143, 0.15096111005028326, 0.13932913245496786, 0.14362548532875055, 0.14410285787028196, 0.16508338107058756, 0.14601234803640759]
# }
# {
# sitename:Hunter
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.636111, -44.120833)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.14
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:101.85711302293483
# trend_params:{'slope': -0.006722689075630255, 'intercept': 13.507749766573301}
# category:N
# analog_years:[1980, 1982, 1994, 1998, 2009, 2010, 2014]
# weights:[0.15250390312381104, 0.11189829574526704, 0.1414833182456279, 0.13833457970900417, 0.16462654648981237, 0.16541373112396832, 0.12573962556250914]
# }
# {
# sitename:Mistake
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.015261, -44.843612)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-1.14
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:44.11061086498545
# trend_params:{'slope': 0.003267973856209143, 'intercept': -6.481699346405213}
# category:WB
# analog_years:[1983, 1984, 1991, 1992, 1993, 2001, 2007]
# weights:[0.13286532720083924, 0.13894133785201324, 0.14035342532074557, 0.14055515210199304, 0.14075687888324054, 0.14237069313322034, 0.16415718550794803]
# }
# {
# sitename:Pyke
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.178333, -44.803611)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.1
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:57.680550981802064
# trend_params:{'slope': 0.003267973856209143, 'intercept': -6.481699346405213}
# category:N
# analog_years:[1980, 1988, 2005, 2009, 2010, 2011, 2014]
# weights:[0.14886095836606444, 0.1540979313956533, 0.16522649908352965, 0.16548834773500923, 0.10172820109976427, 0.10238282272846289, 0.1622152395915162]
# }
# {
# sitename:Falls Creek
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.015937, -44.824221)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.71
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:45.057254239109
# trend_params:{'slope': 0.003267973856209143, 'intercept': -6.481699346405213}
# category:WB
# analog_years:[1983, 1984, 1991, 1992, 1993, 2001, 2007]
# weights:[0.05379216662893347, 0.16445551279148737, 0.16623651045204144, 0.16585918043921222, 0.165481850426383, 0.16246321032374925, 0.12171156893819328]
# }
# {
# sitename:Pear Drop
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.849048, -44.251904)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.69
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:123.27337655298903
# trend_params:{'slope': -0.006722689075630255, 'intercept': 13.507749766573301}
# category:WB
# analog_years:[1983, 1984, 1993, 2002, 2003, 2004, 2007]
# weights:[0.11667743185634943, 0.16506911251776257, 0.13720306018458714, 0.14030343481318808, 0.14064792088303263, 0.1580731745826695, 0.1420258651624108]
# }
# {
# sitename:Clarke
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.451667, -43.873611)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.13
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:132.51511287932962
# trend_params:{'slope': -0.006722689075630255, 'intercept': 13.507749766573301}
# category:N
# analog_years:[1980, 1982, 1994, 1998, 2009, 2010, 2014]
# weights:[0.15339511757098154, 0.1119152443559898, 0.1421372521426801, 0.13892071916316542, 0.16338647313859891, 0.1641906063834776, 0.12605458724510665]
# }
# {
# sitename:Browning Creek
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.836463, -43.850548)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.62
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:128.39056026439624
# trend_params:{'slope': -0.006722689075630255, 'intercept': 13.507749766573301}
# category:B
# analog_years:[1991, 1992, 1995, 1997, 2000, 2001, 2005]
# weights:[0.16565255184403324, 0.12377719828359346, 0.12129365177918518, 0.11963795410957966, 0.15820191233080835, 0.1573740634960056, 0.15406266815679456]
# }
# {
# sitename:Gunn
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.327343, -43.368294)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.59
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -42.5]
# distance_point:100.09698050373754
# trend_params:{'slope': -0.011017740429505127, 'intercept': 22.053221288515395}
# category:B
# analog_years:[1984, 1988, 2000, 2002, 2005, 2009, 2010]
# weights:[0.1604667550491474, 0.1245906338457133, 0.15031710201010426, 0.1474984174758441, 0.14327039067445388, 0.13763302160593358, 0.1362236793388035]
# }
# {
# sitename:Taramakau
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.486667, -42.899444)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.69
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[172.5, -42.5]
# distance_point:93.90851968394558
# trend_params:{'slope': -0.018860877684407102, 'intercept': 37.71914098972924}
# category:B
# analog_years:[1991, 1992, 1994, 1997, 2000, 2002, 2010]
# weights:[0.13100340915887496, 0.1650263273900101, 0.12429141995122239, 0.11757943074356898, 0.15040836805624774, 0.1459337085844791, 0.1657573361155967]
# }

# %% [markdown]
# ### the jsons file describing the data and metadata for each proxy are now in the directory {ens_jsons}

# %%
# !ls -ltr {ens_jsons}
# Out:
# total 96
# -rw-r--r-- 1 nicolasf nicolasf 769 Jun  6 11:09  Rarotonga.json
# -rw-r--r-- 1 nicolasf nicolasf 771 Jun  6 11:09  Amedee.json
# -rw-r--r-- 1 nicolasf nicolasf 777 Jun  6 11:09  Oroko.json
# -rw-r--r-- 1 nicolasf nicolasf 779 Jun  6 11:09  Greenlaw.json
# -rw-r--r-- 1 nicolasf nicolasf 780 Jun  6 11:09  Crow.json
# -rw-r--r-- 1 nicolasf nicolasf 781 Jun  6 11:09  Cameron.json
# -rw-r--r-- 1 nicolasf nicolasf 776 Jun  6 11:09  Avoca.json
# -rw-r--r-- 1 nicolasf nicolasf 781 Jun  6 11:09  Temple.json
# -rw-r--r-- 1 nicolasf nicolasf 783 Jun  6 11:09  Hopkins.json
# -rw-r--r-- 1 nicolasf nicolasf 782 Jun  6 11:09  Turnbull.json
# -rw-r--r-- 1 nicolasf nicolasf 775 Jun  6 11:09  Jollie.json
# -rw-r--r-- 1 nicolasf nicolasf 777 Jun  6 11:09  Cass.json
# -rw-r--r-- 1 nicolasf nicolasf 778 Jun  6 11:09  Caples.json
# -rw-r--r-- 1 nicolasf nicolasf 779 Jun  6 11:09  Fraser.json
# -rw-r--r-- 1 nicolasf nicolasf 780 Jun  6 11:09  Frances.json
# -rw-r--r-- 1 nicolasf nicolasf 781 Jun  6 11:09  Hunter.json
# -rw-r--r-- 1 nicolasf nicolasf 782 Jun  6 11:09  Mistake.json
# -rw-r--r-- 1 nicolasf nicolasf 776 Jun  6 11:09  Pyke.json
# -rw-r--r-- 1 nicolasf nicolasf 782 Jun  6 11:09 'Falls Creek.json'
# -rw-r--r-- 1 nicolasf nicolasf 784 Jun  6 11:09 'Pear Drop.json'
# -rw-r--r-- 1 nicolasf nicolasf 779 Jun  6 11:09  Clarke.json
# -rw-r--r-- 1 nicolasf nicolasf 789 Jun  6 11:09 'Browning Creek.json'
# -rw-r--r-- 1 nicolasf nicolasf 776 Jun  6 11:09  Gunn.json
# -rw-r--r-- 1 nicolasf nicolasf 780 Jun  6 11:09  Taramakau.json
