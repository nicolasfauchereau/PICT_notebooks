# %% [markdown]
# # create a set of proxies from a CSV file containing the relevant information for each proxy

# %%
# %matplotlib inline

# %%
import os 
import sys
import pathlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### import the development version of paleopy

# %%
sys.path.insert(0, '../')

# %%
from paleopy import proxy 
from paleopy import analogs
from paleopy.plotting import scalar_plot

# %% [markdown]
# ### determine the current working directory

# %%
cwd = pathlib.Path.cwd()

# %%
print(cwd)
# Out:
# /home/nicolasf/research/PICT_notebooks/notebooks

# %% [markdown]
# #### defines the folder where the JSON files are (for the datasets) and where to save the proxy JSON files

# %%
djsons = cwd.parent / 'jsons'

# %%
pjsons = djsons / 'proxies'

# %%
if not djsons.exists(): 
    djsons.mkdir()

# %%
if not pjsons.exists(): 
    pjsons.mkdir()

# %% [markdown]
# ### defines the name of the directory (contained in djsons / proxies) where the ensemble will be saved, and creates it if not already existing

# %%
ens_dir_name = 'LIANZSWP'

# %%
ens_jsons = pjsons / ens_dir_name

# %%
if not ens_jsons.exists(): 
    ens_jsons.mkdir()

# %% [markdown]
# ### read the the  information for each proxy from a csv file

# %%
proxies = pd.read_excel('../datasets/Proxies_list.xlsx')

# %%
proxies.head()
# Out:
#     sitename        lat         lon  value dataset variable measurement  \
# 0  Rarotonga -21.230000 -159.820000   0.60   ersst      sst   delta O18
# 1     Amedee -22.480000  166.470000  -0.26   ersst      sst   delta O19
# 2      Oroko -43.222615  170.307329  -0.42    ncep    Tmean   delta O20
# 3   Greenlaw -43.006108  171.419497  -0.26    ncep    Tmean   delta O21
# 4       Crow -43.346222  170.998122  -0.62    ncep    Tmean   delta O22
#
#   dating_convention   calendar chronology season  qualitative  calc_anoms  \
# 0          absolute  gregorian   historic    DJF            0           1
# 1          absolute  gregorian   historic    DJF            0           1
# 2          absolute  gregorian   historic    DJF            0           1
# 3          absolute  gregorian   historic    DJF            0           1
# 4          absolute  gregorian   historic    DJF            0           1
#
#    detrend     method
# 0        1  quintiles
# 1        2  quintiles
# 2        3  quintiles
# 3        4  quintiles
# 4        5  quintiles

# %% [markdown]
# ### The code below loops over each row, instantiates a proxy instance, find the analog years, then saves the data and metadata to disk in a json file in the ensemble directory name

# %%
for i, row in proxies.iterrows(): 
    p = proxy(sitename= row['sitename'], \
          lon = row['lon'], \
          lat = row['lat'], \
          djsons = djsons, \
          pjsons = ens_jsons, \
          pfname = '{}.json'.format(row['sitename']), \
          dataset = row['dataset'], \
          variable = row['variable'], \
          measurement = row['measurement'], \
          dating_convention = row['dating_convention'], \
          calendar = row['calendar'],\
          chronology = row['chronology'], \
          season = row['season'], \
          value = row['value'], \
          qualitative = row['qualitative'], \
          calc_anoms = row['calc_anoms'], \
          detrend = row['detrend'], \
          method = row['method'])
    p.find_analogs()
    p.proxy_repr(pprint=True, outfile=True)
# Out:
# {
# sitename:Rarotonga
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(200.18, -21.23)
# aspect:None
# elevation:None
# season:DJF
# dataset:ersst
# variable:sst
# calc_anoms:True
# detrend:True
# value:0.6
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[200.0, -22.0]
# distance_point:87.56368858840081
# trend_params:{'slope': 0.030535947029886677, 'intercept': -60.96501637775516}
# category:WA
# analog_years:[1982, 1997, 1999, 2000, 2001, 2006, 2009]
# weights:[0.15645480307020584, 0.12800536294956205, 0.13090508326029401, 0.16334634614636281, 0.15762466128135916, 0.1220029495538857, 0.1416607937383304]
# }
# {
# sitename:Amedee
# proxy_type:None
# measurement:delta O19
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(166.47, -22.48)
# aspect:None
# elevation:None
# season:DJF
# dataset:ersst
# variable:sst
# calc_anoms:True
# detrend:True
# value:-0.26
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[166.0, -22.0]
# distance_point:71.98760982961697
# trend_params:{'slope': 0.008158729976368332, 'intercept': -16.257205985829476}
# category:B
# analog_years:[1983, 1987, 1997, 2001, 2003, 2013, 2014]
# weights:[0.12030582528225524, 0.14130672325982882, 0.1460232361735553, 0.15477112280550417, 0.15052130006811879, 0.12187469005527739, 0.1651971023554603]
# }
# {
# sitename:Oroko
# proxy_type:None
# measurement:delta O20
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.307329, -43.222615)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.42
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -42.5]
# distance_point:84.11208434388203
# trend_params:{'slope': -0.010740051394194554, 'intercept': 21.494354317769275}
# category:B
# analog_years:[1980, 1992, 2000, 2001, 2002, 2005, 2010]
# weights:[0.1371965569781615, 0.14050948595789184, 0.16530091723364615, 0.13453891538699117, 0.1665181223586947, 0.12250992072350948, 0.13342608136110512]
# }
# {
# sitename:Greenlaw
# proxy_type:None
# measurement:delta O21
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.419497, -43.006108)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.26
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[172.5, -42.5]
# distance_point:104.57596044098004
# trend_params:{'slope': -0.020944575657920246, 'intercept': 41.87305525673762}
# category:B
# analog_years:[1991, 1992, 1994, 1997, 2000, 2002, 2010]
# weights:[0.13738349098508673, 0.13423517944336696, 0.15921320855250568, 0.16250357361804696, 0.13975942260580124, 0.13350552470044413, 0.13339960009474827]
# }
# {
# sitename:Crow
# proxy_type:None
# measurement:delta O22
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.998122, -43.346222)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.62
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -42.5]
# distance_point:124.25433418836984
# trend_params:{'slope': -0.010740051394194554, 'intercept': 21.494354317769275}
# category:B
# analog_years:[1980, 1992, 2000, 2001, 2002, 2005, 2010]
# weights:[0.129177737012279, 0.16420453555580453, 0.14687419063842327, 0.12750430161842832, 0.14764062737112646, 0.1577950236383774, 0.126803584165561]
# }
# {
# sitename:Cameron
# proxy_type:None
# measurement:delta O23
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.505139, -42.934067)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.81
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[172.5, -42.5]
# distance_point:94.46733893961293
# trend_params:{'slope': -0.020944575657920246, 'intercept': 41.87305525673762}
# category:WB
# analog_years:[1983, 1984, 1993, 2003, 2004, 2005, 2007]
# weights:[0.13500513662618582, 0.1618498466844527, 0.12336248315291025, 0.1302952428222038, 0.16123261217721352, 0.14834895947130913, 0.13990571906572477]
# }
# {
# sitename:Avoca
# proxy_type:None
# measurement:delta O24
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.405812, -43.043031)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.53
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[172.5, -42.5]
# distance_point:107.73975744104352
# trend_params:{'slope': -0.020944575657920246, 'intercept': 41.87305525673762}
# category:B
# analog_years:[1991, 1992, 1994, 1997, 2000, 2002, 2010]
# weights:[0.16051743220580109, 0.15459689924752107, 0.10373110812603097, 0.1099187787415854, 0.16498547206801112, 0.15322475265516694, 0.15302555695588346]
# }
# {
# sitename:Temple
# proxy_type:None
# measurement:delta O25
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.709872, -44.146466)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.79
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:97.58982094997447
# trend_params:{'slope': -0.007048610523412654, 'intercept': 14.152330697217245}
# category:WB
# analog_years:[1983, 1984, 1992, 1993, 2002, 2003, 2007]
# weights:[0.11224227146945491, 0.16121397971699733, 0.15921680311740918, 0.14499599158961243, 0.13029849085833703, 0.16479995664567806, 0.12723250660251106]
# }
# {
# sitename:Hopkins
# proxy_type:None
# measurement:delta O26
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.887499, -43.942569)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.39
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:117.84526868991945
# trend_params:{'slope': -0.007048610523412654, 'intercept': 14.152330697217245}
# category:B
# analog_years:[1991, 1995, 1997, 2000, 2001, 2004, 2005]
# weights:[0.13743027796903914, 0.12716145202549448, 0.14390981540930983, 0.1608506623027443, 0.1397289999271982, 0.14210125797571682, 0.14881753439049697]
# }
# {
# sitename:Turnbull
# proxy_type:None
# measurement:delta O27
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.850303, -43.877607)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.4
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:125.29023646426968
# trend_params:{'slope': -0.007048610523412654, 'intercept': 14.152330697217245}
# category:B
# analog_years:[1991, 1995, 1997, 2000, 2001, 2004, 2005]
# weights:[0.1380618116065838, 0.12488044995904624, 0.14203069364962798, 0.1620441727152681, 0.14041569185481242, 0.14284487270649812, 0.14972230750816332]
# }
# {
# sitename:Jollie
# proxy_type:None
# measurement:delta O28
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.33, -43.697778)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.99
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -42.5]
# distance_point:135.76947455586478
# trend_params:{'slope': -0.010740051394194554, 'intercept': 21.494354317769275}
# category:WB
# analog_years:[1983, 1984, 1991, 1993, 2003, 2004, 2007]
# weights:[0.0959839787918646, 0.13362559503761576, 0.1485229743441154, 0.1624055287655427, 0.16415262181092283, 0.13769043730375397, 0.15761886394618485]
# }
# {
# sitename:Cass
# proxy_type:None
# measurement:delta O29
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.315493, -43.652675)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.16
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -42.5]
# distance_point:130.62568491574098
# trend_params:{'slope': -0.010740051394194554, 'intercept': 21.494354317769275}
# category:N
# analog_years:[1988, 1994, 1995, 1997, 1998, 2009, 2014]
# weights:[0.1405067418735753, 0.16245457132042215, 0.12513908860485556, 0.1479616566042067, 0.13941416900812012, 0.16267668355830042, 0.12184708903051972]
# }
# {
# sitename:Caples
# proxy_type:None
# measurement:delta O30
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.182845, -44.801851)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.35
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:58.084070977038905
# trend_params:{'slope': -0.002663327331970378, 'intercept': 5.364626702273911}
# category:B
# analog_years:[1991, 1995, 1997, 2000, 2002, 2003, 2009]
# weights:[0.10167598135694365, 0.16582173502573244, 0.1662497307080829, 0.16462439083531816, 0.14118074096409586, 0.10248744262978754, 0.1579599784800393]
# }
# {
# sitename:Fraser
# proxy_type:None
# measurement:delta O31
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.186884, -44.786354)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.21
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:59.056131286896935
# trend_params:{'slope': -0.002663327331970378, 'intercept': 5.364626702273911}
# category:N
# analog_years:[1980, 1988, 1994, 1998, 2005, 2010, 2014]
# weights:[0.1296114754407525, 0.14257907377638623, 0.11433190934857283, 0.15892000593555872, 0.16560152885611032, 0.1229541161395405, 0.1660018905030789]
# }
# {
# sitename:Frances
# proxy_type:None
# measurement:delta O32
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.395713, -44.596521)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.41
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:83.65886439139706
# trend_params:{'slope': -0.002663327331970378, 'intercept': 5.364626702273911}
# category:B
# analog_years:[1991, 1995, 1997, 2000, 2002, 2003, 2009]
# weights:[0.12964027926445412, 0.15419653515950754, 0.15322284555531082, 0.15196869136512317, 0.13387896612552022, 0.13026642372357025, 0.14682625880651387]
# }
# {
# sitename:Hunter
# proxy_type:None
# measurement:delta O33
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.646667, -44.094444)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.88
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:104.4478564149211
# trend_params:{'slope': -0.007048610523412654, 'intercept': 14.152330697217245}
# category:WB
# analog_years:[1983, 1984, 1992, 1993, 2002, 2003, 2007]
# weights:[0.11614328944100144, 0.15523191357633637, 0.15316532443096362, 0.15003537614222476, 0.13482705881984777, 0.15894252234167894, 0.1316545152479471]
# }
# {
# sitename:Hunter
# proxy_type:None
# measurement:delta O34
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.636111, -44.120833)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.14
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:101.85711302293483
# trend_params:{'slope': -0.007048610523412654, 'intercept': 14.152330697217245}
# category:B
# analog_years:[1991, 1995, 1997, 2000, 2001, 2004, 2005]
# weights:[0.130394434292227, 0.1625807547031062, 0.1609196269090126, 0.1441445245648176, 0.13174401224901508, 0.1331367631899152, 0.13707988409190633]
# }
# {
# sitename:Mistake
# proxy_type:None
# measurement:delta O35
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.015261, -44.843612)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-1.14
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:44.11061086498545
# trend_params:{'slope': -0.002663327331970378, 'intercept': 5.364626702273911}
# category:WB
# analog_years:[1983, 1984, 1992, 1993, 2001, 2004, 2007]
# weights:[0.13302655044270587, 0.1379934494661589, 0.13874665512357406, 0.14716481098050171, 0.14230854031301887, 0.1366329827779569, 0.16412701089608367]
# }
# {
# sitename:Pyke
# proxy_type:None
# measurement:delta O36
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.178333, -44.803611)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.1
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:57.680550981802064
# trend_params:{'slope': -0.002663327331970378, 'intercept': 5.364626702273911}
# category:N
# analog_years:[1980, 1988, 1994, 1998, 2005, 2010, 2014]
# weights:[0.13882921914423862, 0.15460481214454913, 0.12024102650804286, 0.15884913502053635, 0.148129235792008, 0.13073027992091638, 0.14861629146970853]
# }
# {
# sitename:Falls Creek
# proxy_type:None
# measurement:delta O37
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.015937, -44.824221)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.71
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[167.5, -45.0]
# distance_point:45.057254239109
# trend_params:{'slope': -0.002663327331970378, 'intercept': 5.364626702273911}
# category:WB
# analog_years:[1983, 1984, 1992, 1993, 2001, 2004, 2007]
# weights:[0.07562892494388991, 0.15815006900970507, 0.15935342128633997, 0.16053072069298002, 0.16504403527686695, 0.15597653158281935, 0.12531629720739854]
# }
# {
# sitename:Pear Drop
# proxy_type:None
# measurement:delta O38
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.849048, -44.251904)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.69
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:123.27337655298903
# trend_params:{'slope': -0.007048610523412654, 'intercept': 14.152330697217245}
# category:WB
# analog_years:[1983, 1984, 1992, 1993, 2002, 2003, 2007]
# weights:[0.11147354099422475, 0.16596833074926876, 0.16554735023702352, 0.14128306122543918, 0.12790670446993255, 0.16270469378186397, 0.12511631854224728]
# }
# {
# sitename:Clarke
# proxy_type:None
# measurement:delta O39
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.451667, -43.873611)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.13
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:132.51511287932962
# trend_params:{'slope': -0.007048610523412654, 'intercept': 14.152330697217245}
# category:B
# analog_years:[1991, 1995, 1997, 2000, 2001, 2004, 2005]
# weights:[0.13046031008450634, 0.1634195118009003, 0.16030127666290667, 0.14390219035125798, 0.1317796370813592, 0.13314116933444586, 0.13699590468462364]
# }
# {
# sitename:Browning Creek
# proxy_type:None
# measurement:delta O40
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.836463, -43.850548)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.62
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -45.0]
# distance_point:128.39056026439624
# trend_params:{'slope': -0.007048610523412654, 'intercept': 14.152330697217245}
# category:B
# analog_years:[1991, 1995, 1997, 2000, 2001, 2004, 2005]
# weights:[0.16596429879495797, 0.09754505647787742, 0.11421487907605066, 0.142653743424445, 0.16367635660222613, 0.16131522316371308, 0.1546304424607298]
# }
# {
# sitename:Gunn
# proxy_type:None
# measurement:delta O41
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.327343, -43.368294)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.59
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[170.0, -42.5]
# distance_point:100.09698050373754
# trend_params:{'slope': -0.010740051394194554, 'intercept': 21.494354317769275}
# category:B
# analog_years:[1980, 1992, 2000, 2001, 2002, 2005, 2010]
# weights:[0.12897747698423032, 0.1662557783273033, 0.14822663168580624, 0.127157213022883, 0.1490603161939259, 0.15392756972877744, 0.12639501405707385]
# }
# {
# sitename:Taramakau
# proxy_type:None
# measurement:delta O42
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.486667, -42.899444)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:Tmean
# calc_anoms:True
# detrend:True
# value:-0.69
# climatology:(1981, 2010)
# period:(1979, 2014)
# extracted_coords:[172.5, -42.5]
# distance_point:93.90851968394558
# trend_params:{'slope': -0.020944575657920246, 'intercept': 41.87305525673762}
# category:WB
# analog_years:[1983, 1984, 1993, 2003, 2004, 2005, 2007]
# weights:[0.13576326608759764, 0.15601220832804316, 0.1269812223555485, 0.132210597148784, 0.16374443432863364, 0.14582850044740894, 0.13945977130398413]
# }

# %%
# !ls -ltr {ens_jsons}
# Out:
# total 96
# -rw-rw-r-- 1 nicolasf nicolasf 771 Jun 24 09:31 Rarotonga.json
# -rw-rw-r-- 1 nicolasf nicolasf 770 Jun 24 09:31 Amedee.json
# -rw-rw-r-- 1 nicolasf nicolasf 778 Jun 24 09:31 Oroko.json
# -rw-rw-r-- 1 nicolasf nicolasf 783 Jun 24 09:31 Greenlaw.json
# -rw-rw-r-- 1 nicolasf nicolasf 775 Jun 24 09:31 Crow.json
# -rw-rw-r-- 1 nicolasf nicolasf 780 Jun 24 09:31 Cameron.json
# -rw-rw-r-- 1 nicolasf nicolasf 779 Jun 24 09:31 Avoca.json
# -rw-rw-r-- 1 nicolasf nicolasf 782 Jun 24 09:31 Temple.json
# -rw-rw-r-- 1 nicolasf nicolasf 781 Jun 24 09:31 Hopkins.json
# -rw-rw-r-- 1 nicolasf nicolasf 781 Jun 24 09:31 Turnbull.json
# -rw-rw-r-- 1 nicolasf nicolasf 776 Jun 24 09:31 Jollie.json
# -rw-rw-r-- 1 nicolasf nicolasf 778 Jun 24 09:31 Cass.json
# -rw-rw-r-- 1 nicolasf nicolasf 779 Jun 24 09:31 Caples.json
# -rw-rw-r-- 1 nicolasf nicolasf 778 Jun 24 09:31 Fraser.json
# -rw-rw-r-- 1 nicolasf nicolasf 781 Jun 24 09:31 Frances.json
# -rw-rw-r-- 1 nicolasf nicolasf 776 Jun 24 09:31 Hunter.json
# -rw-rw-r-- 1 nicolasf nicolasf 780 Jun 24 09:31 Mistake.json
# -rw-rw-r-- 1 nicolasf nicolasf 776 Jun 24 09:31 Pyke.json
# -rw-rw-r-- 1 nicolasf nicolasf 784 Jun 24 09:31 Falls Creek.json
# -rw-rw-r-- 1 nicolasf nicolasf 786 Jun 24 09:31 Pear Drop.json
# -rw-rw-r-- 1 nicolasf nicolasf 780 Jun 24 09:31 Clarke.json
# -rw-rw-r-- 1 nicolasf nicolasf 787 Jun 24 09:31 Browning Creek.json
# -rw-rw-r-- 1 nicolasf nicolasf 776 Jun 24 09:31 Gunn.json
# -rw-rw-r-- 1 nicolasf nicolasf 781 Jun 24 09:31 Taramakau.json
