# %% [markdown]
# # create a set of proxies from a CSV file containing the relevant information for each proxy

# %%
# %matplotlib inline

# %%
import os 
import sys
import pathlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### import the development version of paleopy

# %%
from paleopy import proxy 
from paleopy import analogs
from paleopy.plotting import scalar_plot

# %% [markdown]
# ### determine the current working directory

# %%
cwd = pathlib.Path.cwd()

# %%
print(cwd)
# Out:
# /home/nicolasf/research/PICT_notebooks/notebooks

# %% [markdown]
# #### defines the folder where the JSON files are (for the datasets) and where to save the proxy JSON files

# %%
djsons = cwd.parent.joinpath('jsons')

# %%
pjsons = djsons.joinpath('proxies')

# %%
djsons.mkdir(parents=True, exist_ok=True)

# %%
pjsons.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### defines the name of the directory (contained in djsons / proxies) where the ensemble will be saved, and creates it if not already existing

# %%
ens_dir_name = 'LIANZSWP'

# %%
ens_jsons = pjsons.joinpath(ens_dir_name)

# %%
ens_jsons.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### read the the  information for each proxy from a csv file

# %%
proxies = pd.read_csv('../excel//Proxies_list.csv')

# %%
proxies.head()
# Out:
#     sitename        lat         lon  value dataset variable measurement  \
# 0  Rarotonga -21.230000 -159.820000   0.60   ersst      sst   delta O18
# 1     Amedee -22.480000  166.470000  -0.26   ersst      sst   delta O18
# 2      Oroko -43.222615  170.307329  -0.42    ncep    TMean   delta O18
# 3   Greenlaw -43.006108  171.419497  -0.26    ncep    TMean   delta O18
# 4       Crow -43.346222  170.998122  -0.62    ncep    TMean   delta O18
#
#   dating_convention   calendar chronology season  qualitative  calc_anoms  \
# 0          absolute  gregorian   historic    DJF            0           1
# 1          absolute  gregorian   historic    DJF            0           1
# 2          absolute  gregorian   historic    DJF            0           1
# 3          absolute  gregorian   historic    DJF            0           1
# 4          absolute  gregorian   historic    DJF            0           1
#
#    detrend     method
# 0        1  quintiles
# 1        2  quintiles
# 2        3  quintiles
# 3        4  quintiles
# 4        5  quintiles

# %% [markdown]
# ### The code below loops over each row, instantiates a proxy instance, find the analog years, then saves the data and metadata to disk in a json file in the ensemble directory name

# %%
for i, row in proxies.iterrows(): 
    p = proxy(sitename= row['sitename'], \
          lon = row['lon'], \
          lat = row['lat'], \
          djsons = djsons, \
          pjsons = ens_jsons, \
          pfname = '{}.json'.format(row['sitename']), \
          dataset = row['dataset'], \
          variable = row['variable'], \
          measurement = row['measurement'], \
          dating_convention = row['dating_convention'], \
          calendar = row['calendar'],\
          chronology = row['chronology'], \
          season = row['season'], \
          value = row['value'], \
          qualitative = row['qualitative'], \
          calc_anoms = row['calc_anoms'], \
          detrend = row['detrend'], \
          method = row['method'])
    p.find_analogs()
    p.proxy_repr(pprint=True, outfile=True)
# Out:
# {
# sitename:Rarotonga
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(200.18, -21.23)
# aspect:None
# elevation:None
# season:DJF
# dataset:ersst
# variable:sst
# calc_anoms:True
# detrend:True
# value:0.6
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[200.0, -22.0]
# distance_point:87.56368858840081
# trend_params:{'slope': 0.022069378447875616, 'intercept': -44.105259409362375}
# category:WA
# analog_years:[1982, 1994, 1997, 1999, 2000, 2001, 2006, 2009]
# weights:[0.13783501335974088, 0.14217311248257797, 0.13208010210728532, 0.10404673433198279, 0.11468950854914021, 0.1302975275719365, 0.11943878543179427, 0.11943921616554208]
# }
# {
# sitename:Amedee
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(166.47, -22.48)
# aspect:None
# elevation:None
# season:DJF
# dataset:ersst
# variable:sst
# calc_anoms:True
# detrend:True
# value:-0.26
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[166.0, -22.0]
# distance_point:71.98760982961697
# trend_params:{'slope': 0.005114135121911515, 'intercept': -10.190632255936688}
# category:B
# analog_years:[1981, 1987, 1992, 1997, 2003, 2010, 2013, 2015]
# weights:[0.10861935875906457, 0.12925226908260654, 0.13878416929060589, 0.11044692264466098, 0.13244612859211416, 0.1243545733829855, 0.12008422791065011, 0.13601235033731224]
# }
# {
# sitename:Oroko
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.307329, -43.222615)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.42
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -42.5]
# distance_point:84.11208434388203
# trend_params:{'slope': 0.012351469668542846, 'intercept': -24.499541380029196}
# category:B
# analog_years:[1984, 2000, 2001, 2002, 2005, 2009, 2010, 2014]
# weights:[0.1402425926036148, 0.12314412654163516, 0.13479867908938775, 0.12100681828388767, 0.11780085589726627, 0.11352623938177128, 0.11245758525289769, 0.13702310294953943]
# }
# {
# sitename:Greenlaw
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.419497, -43.006108)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.26
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[172.5, -42.5]
# distance_point:104.57596044098004
# trend_params:{'slope': 0.006566604127579731, 'intercept': -12.935480508651228}
# category:B
# analog_years:[1983, 1984, 1991, 1992, 1994, 1997, 2012, 2017]
# weights:[0.11473057005326094, 0.1142466303973098, 0.1354247515315539, 0.11037511314970042, 0.13397293256370035, 0.13252111359584678, 0.13588656823180434, 0.12284232047682345]
# }
# {
# sitename:Crow
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.998122, -43.346222)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.62
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -42.5]
# distance_point:124.25433418836984
# trend_params:{'slope': 0.012351469668542846, 'intercept': -24.499541380029196}
# category:B
# analog_years:[1984, 2000, 2001, 2002, 2005, 2009, 2010, 2014]
# weights:[0.11988546314402646, 0.1390900175409948, 0.10319486411863907, 0.13574766691233667, 0.13073414096934924, 0.124049439712033, 0.12237826439770419, 0.12492014320491661]
# }
# {
# sitename:Cameron
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.505139, -42.934067)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.81
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[172.5, -42.5]
# distance_point:94.46733893961293
# trend_params:{'slope': 0.006566604127579731, 'intercept': -12.935480508651228}
# category:WB
# analog_years:[1993, 2000, 2002, 2003, 2004, 2005, 2007, 2010]
# weights:[0.12029591951101382, 0.1405882865068468, 0.14111365847019688, 0.11766905969426356, 0.13074081449666364, 0.11714368773091353, 0.10328387498348827, 0.1291646986066135]
# }
# {
# sitename:Avoca
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.405812, -43.043031)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.53
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[172.5, -42.5]
# distance_point:107.73975744104352
# trend_params:{'slope': 0.006566604127579731, 'intercept': -12.935480508651228}
# category:B
# analog_years:[1983, 1984, 1991, 1992, 1994, 1997, 2012, 2017]
# weights:[0.1297309021395486, 0.1289589000808765, 0.12297110506580379, 0.12278288361149918, 0.12528711124182032, 0.1276031174178369, 0.09999485331960897, 0.14267112712300575]
# }
# {
# sitename:Temple
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.709872, -44.146466)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.79
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -45.0]
# distance_point:97.58982094997447
# trend_params:{'slope': 0.017260787992495304, 'intercept': -34.268501146549916}
# category:WB
# analog_years:[1983, 1993, 2001, 2002, 2003, 2004, 2005, 2007]
# weights:[0.11703158792127581, 0.12333475093186262, 0.14165022203320907, 0.11724251088583218, 0.11656559532516231, 0.12896099838177935, 0.14135640143839662, 0.11385793308248203]
# }
# {
# sitename:Hopkins
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.887499, -43.942569)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.39
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -45.0]
# distance_point:117.84526868991945
# trend_params:{'slope': 0.017260787992495304, 'intercept': -34.268501146549916}
# category:B
# analog_years:[1984, 1991, 1995, 1997, 2000, 2009, 2010, 2017]
# weights:[0.13513701178245266, 0.12282964876875414, 0.13596387292074416, 0.13948026235322936, 0.10700589632256974, 0.12513568676614453, 0.12337749204990231, 0.11107012903620309]
# }
# {
# sitename:Turnbull
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.850303, -43.877607)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.4
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -45.0]
# distance_point:125.29023646426968
# trend_params:{'slope': 0.017260787992495304, 'intercept': -34.268501146549916}
# category:B
# analog_years:[1984, 1991, 1995, 1997, 2000, 2009, 2010, 2017]
# weights:[0.13595887267052228, 0.12329018635821178, 0.13471298737065798, 0.13833261203131803, 0.10700187538524045, 0.12566392571900667, 0.12385411338867702, 0.11118542707636576]
# }
# {
# sitename:Jollie
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.33, -43.697778)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.99
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -42.5]
# distance_point:135.76947455586478
# trend_params:{'slope': 0.012351469668542846, 'intercept': -24.499541380029196}
# category:WB
# analog_years:[1983, 1991, 1992, 1993, 2003, 2004, 2007, 2017]
# weights:[0.1272654520687895, 0.1265230716839775, 0.1282044951472844, 0.12988591861059084, 0.09363698280265612, 0.13733270900732175, 0.1322884386174015, 0.12486293206197836]
# }
# {
# sitename:Cass
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.315493, -43.652675)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.16
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -42.5]
# distance_point:130.62568491574098
# trend_params:{'slope': 0.012351469668542846, 'intercept': -24.499541380029196}
# category:N
# analog_years:[1988, 1994, 1995, 1997, 1998, 2008, 2012, 2013]
# weights:[0.14221275641744183, 0.11695101446026254, 0.13335724694540968, 0.13082710138197187, 0.12956202860025315, 0.13466203340432686, 0.1055813730043077, 0.10684644578602642]
# }
# {
# sitename:Caples
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.182845, -44.801851)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.35
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[167.5, -45.0]
# distance_point:58.084070977038905
# trend_params:{'slope': 0.018261413383364598, 'intercept': -36.3525849489264}
# category:N
# analog_years:[1980, 1988, 2005, 2008, 2009, 2010, 2011, 2016]
# weights:[0.10753374295349097, 0.11740519434419941, 0.1383820285494543, 0.11956034854336937, 0.14239653146947698, 0.12202821139104636, 0.12326214281488486, 0.1294317999340778]
# }
# {
# sitename:Fraser
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.186884, -44.786354)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.21
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[167.5, -45.0]
# distance_point:59.056131286896935
# trend_params:{'slope': 0.018261413383364598, 'intercept': -36.3525849489264}
# category:N
# analog_years:[1980, 1988, 2005, 2008, 2009, 2010, 2011, 2016]
# weights:[0.10439676451218831, 0.11907610635484811, 0.1354445779437863, 0.12228092841809987, 0.12810490702245605, 0.12595076387876464, 0.12778568160909703, 0.13696027026075966]
# }
# {
# sitename:Frances
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.395713, -44.596521)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.41
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[167.5, -45.0]
# distance_point:83.65886439139706
# trend_params:{'slope': 0.018261413383364598, 'intercept': -36.3525849489264}
# category:B
# analog_years:[1984, 1995, 1997, 1998, 2000, 2002, 2003, 2014]
# weights:[0.11477977570327717, 0.13847592793147606, 0.13194214469197169, 0.12867525307222014, 0.12214146983271704, 0.11560768659321394, 0.11234079497346239, 0.13603694720166157]
# }
# {
# sitename:Hunter
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.646667, -44.094444)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.88
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -45.0]
# distance_point:104.4478564149211
# trend_params:{'slope': 0.017260787992495304, 'intercept': -34.268501146549916}
# category:WB
# analog_years:[1983, 1993, 2001, 2002, 2003, 2004, 2005, 2007]
# weights:[0.1175254353660822, 0.12468679501012073, 0.13747581299544348, 0.11776507619463729, 0.11699599632625046, 0.1310790747857722, 0.14055213246899148, 0.11391967685270217]
# }
# {
# sitename:Hunter
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.636111, -44.120833)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.14
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -45.0]
# distance_point:101.85711302293483
# trend_params:{'slope': 0.017260787992495304, 'intercept': -34.268501146549916}
# category:N
# analog_years:[1980, 1992, 1994, 1998, 2006, 2008, 2011, 2014]
# weights:[0.10934636967475986, 0.13218518912374816, 0.129101294090701, 0.13474555820954118, 0.1187841518879655, 0.12160628394738558, 0.125839482036516, 0.1283916710293827]
# }
# {
# sitename:Mistake
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.015261, -44.843612)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-1.14
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[167.5, -45.0]
# distance_point:44.11061086498545
# trend_params:{'slope': 0.018261413383364598, 'intercept': -36.3525849489264}
# category:WB
# analog_years:[1983, 1991, 1992, 1993, 2001, 2004, 2007, 2017]
# weights:[0.12324805826582826, 0.12149506629682401, 0.1223712622142311, 0.12324745813163819, 0.1302570254708953, 0.11689203705948646, 0.13420650857531727, 0.12828258398577938]
# }
# {
# sitename:Pyke
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.178333, -44.803611)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.1
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[167.5, -45.0]
# distance_point:57.680550981802064
# trend_params:{'slope': 0.018261413383364598, 'intercept': -36.3525849489264}
# category:N
# analog_years:[1980, 1988, 2005, 2008, 2009, 2010, 2011, 2016]
# weights:[0.10692246216209551, 0.126168917304508, 0.11864665123215228, 0.1303708403022091, 0.10902342366094557, 0.135182454087812, 0.13758826098061344, 0.13609699026966413]
# }
# {
# sitename:Falls Creek
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.015937, -44.824221)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.71
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[167.5, -45.0]
# distance_point:45.057254239109
# trend_params:{'slope': 0.018261413383364598, 'intercept': -36.3525849489264}
# category:WB
# analog_years:[1983, 1991, 1992, 1993, 2001, 2004, 2007, 2017]
# weights:[0.07957595479065789, 0.14170860057153434, 0.14262781189953982, 0.14124993865632826, 0.1302269527106353, 0.13447004730068965, 0.09680880781876991, 0.1333318862518448]
# }
# {
# sitename:Pear Drop
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(168.849048, -44.251904)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.69
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -45.0]
# distance_point:123.27337655298903
# trend_params:{'slope': 0.017260787992495304, 'intercept': -34.268501146549916}
# category:B
# analog_years:[1984, 1991, 1995, 1997, 2000, 2009, 2010, 2017]
# weights:[0.11872428592969157, 0.13172941258831633, 0.1032823808805795, 0.10699813135447218, 0.1372639959934512, 0.12929263419782902, 0.13115050943477496, 0.14155864962088524]
# }
# {
# sitename:Clarke
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.451667, -43.873611)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.13
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -45.0]
# distance_point:132.51511287932962
# trend_params:{'slope': 0.017260787992495304, 'intercept': -34.268501146549916}
# category:N
# analog_years:[1980, 1992, 1994, 1998, 2006, 2008, 2011, 2014]
# weights:[0.10939798953116306, 0.1310985372510195, 0.1296156961400088, 0.135392183742536, 0.11905686282307, 0.12194510662433358, 0.12627747232622927, 0.12721615156163973]
# }
# {
# sitename:Browning Creek
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(169.836463, -43.850548)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.62
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -45.0]
# distance_point:128.39056026439624
# trend_params:{'slope': 0.017260787992495304, 'intercept': -34.268501146549916}
# category:B
# analog_years:[1984, 1991, 1995, 1997, 2000, 2009, 2010, 2017]
# weights:[0.12182083735722993, 0.13830317259359606, 0.10225019707140019, 0.1069594357103618, 0.12621953924536097, 0.13521486754413242, 0.13756948686361276, 0.13166246361430586]
# }
# {
# sitename:Gunn
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(170.327343, -43.368294)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.59
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[170.0, -42.5]
# distance_point:100.09698050373754
# trend_params:{'slope': 0.012351469668542846, 'intercept': -24.499541380029196}
# category:B
# analog_years:[1984, 2000, 2001, 2002, 2005, 2009, 2010, 2014]
# weights:[0.12496146797217841, 0.13545178752579162, 0.10916834072481049, 0.1322891587487521, 0.1275452155831926, 0.12121995802911358, 0.11963864364059404, 0.12972542777556711]
# }
# {
# sitename:Taramakau
# proxy_type:None
# measurement:delta O18
# dating_convention:absolute
# calendar:gregorian
# chronology:historic
# coords:(171.486667, -42.899444)
# aspect:None
# elevation:None
# season:DJF
# dataset:ncep
# variable:TMean
# calc_anoms:True
# detrend:True
# value:-0.69
# climatology:(1981, 2010)
# period:(1979, 2019)
# extracted_coords:[172.5, -42.5]
# distance_point:93.90851968394558
# trend_params:{'slope': 0.006566604127579731, 'intercept': -12.935480508651228}
# category:B
# analog_years:[1983, 1984, 1991, 1992, 1994, 1997, 2012, 2017]
# weights:[0.13882323107411315, 0.13937110423051996, 0.1153951313382401, 0.14196019623251108, 0.11703875080746065, 0.11868237027668117, 0.09908938263565616, 0.12963983340481772]
# }

# %% [markdown]
# ### the jsons file describing the data and metadata for each proxy are now in the directory {ens_jsons}

# %%
# !ls -ltr {ens_jsons}
# Out:
# total 96
# -rw-r--r-- 1 nicolasf nicolasf 800 Jun  6 14:37  Rarotonga.json
# -rw-r--r-- 1 nicolasf nicolasf 798 Jun  6 14:37  Amedee.json
# -rw-r--r-- 1 nicolasf nicolasf 806 Jun  6 14:37  Oroko.json
# -rw-r--r-- 1 nicolasf nicolasf 809 Jun  6 14:37  Greenlaw.json
# -rw-r--r-- 1 nicolasf nicolasf 804 Jun  6 14:37  Crow.json
# -rw-r--r-- 1 nicolasf nicolasf 808 Jun  6 14:37  Cameron.json
# -rw-r--r-- 1 nicolasf nicolasf 805 Jun  6 14:37  Avoca.json
# -rw-r--r-- 1 nicolasf nicolasf 809 Jun  6 14:37  Temple.json
# -rw-r--r-- 1 nicolasf nicolasf 810 Jun  6 14:37  Hopkins.json
# -rw-r--r-- 1 nicolasf nicolasf 810 Jun  6 14:37  Turnbull.json
# -rw-r--r-- 1 nicolasf nicolasf 802 Jun  6 14:37  Jollie.json
# -rw-r--r-- 1 nicolasf nicolasf 806 Jun  6 14:37  Cass.json
# -rw-r--r-- 1 nicolasf nicolasf 805 Jun  6 14:37  Caples.json
# -rw-r--r-- 1 nicolasf nicolasf 806 Jun  6 14:37  Fraser.json
# -rw-r--r-- 1 nicolasf nicolasf 807 Jun  6 14:37  Frances.json
# -rw-r--r-- 1 nicolasf nicolasf 803 Jun  6 14:37  Hunter.json
# -rw-r--r-- 1 nicolasf nicolasf 806 Jun  6 14:37  Mistake.json
# -rw-r--r-- 1 nicolasf nicolasf 799 Jun  6 14:37  Pyke.json
# -rw-r--r-- 1 nicolasf nicolasf 808 Jun  6 14:37 'Falls Creek.json'
# -rw-r--r-- 1 nicolasf nicolasf 810 Jun  6 14:37 'Pear Drop.json'
# -rw-r--r-- 1 nicolasf nicolasf 802 Jun  6 14:37  Clarke.json
# -rw-r--r-- 1 nicolasf nicolasf 816 Jun  6 14:37 'Browning Creek.json'
# -rw-r--r-- 1 nicolasf nicolasf 805 Jun  6 14:37  Gunn.json
# -rw-r--r-- 1 nicolasf nicolasf 810 Jun  6 14:37  Taramakau.json
